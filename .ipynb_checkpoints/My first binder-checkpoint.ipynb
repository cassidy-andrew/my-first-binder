# %%
#Imports

from IPython.display import display, Markdown, Latex
import numpy, math, pandas 
import matplotlib.pyplot as plt
import glob
from IPython.display import display, HTML
import os
import openpyxl

# %%
filenames=sorted(glob.glob("data/DataFor_*.csv"))
SpontelData_dict = {}

for f in filenames:
    name=f[13:-4]
    print(name)
    SpontelData = pandas.read_csv(f)
    SpontelData_dict[name] =  (SpontelData)
    
print(SpontelData_dict)
print(SpontelData_dict['N2O']['Temperature'])    
#SpontelData_dict = pandas.read_csv("data/DataFor_*.csv")
# Out:
# 1-butanol
# 1-pentanol
# N2O
# ammonia
# {'1-butanol':    weight       y   sigma_y  Temperature  sigma_T  Observed_field   IceMu  \
# 0     1.0 -0.0250  0.000928         32.0      0.1     161800000.0  0.4326
# 1     1.0 -0.0292  0.000915         36.0      0.1     159600000.0     NaN
# 2     1.0 -0.0300  0.000884         40.0      0.1     154200000.0     NaN
# 3     1.0 -0.0293  0.000914         44.0      0.1     159400000.0     NaN
# 4     1.0 -0.0291  0.000869         48.0      0.1     151600000.0     NaN
#
#           EAnxt  ymin  ymax  xmin  xmax  ticks
# 0 -2.490000e+09   0.0 -0.05  30.0  50.0    0.0
# 1           NaN   0.0  1.00  30.0  50.0    0.2
# 2           NaN   NaN   NaN   NaN   NaN    0.4
# 3           NaN   NaN   NaN   NaN   NaN    0.6
# 4           NaN   NaN   NaN   NaN   NaN    0.8  , '1-pentanol':    weight       y   sigma_y  Temperature  sigma_T  Observed_field   IceMu  \
# 0     1.0 -0.0250  0.000928         32.0      0.1     161800000.0  0.4256
# ...
